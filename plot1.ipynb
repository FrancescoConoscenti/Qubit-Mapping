# %%
import matplotlib.pyplot as plt
import numpy as np

# Define explicit x and y values for the three datasets
x_values = [1000,10000,100000]
y_values3 = [0.063,0.0047,0.00053]

# Define the width of the bars
bar_width = 0.25

# Create an array of x positions for the first set of bars
r1 = np.arange(len(x_values))

# Create arrays of x positions for the second and third sets of bars, offset by the bar width
r2 = [x + bar_width for x in r1]


# Create the bar plot

plt.bar(r2, y_values3, color='orange', width=bar_width,  label='KL Divergence')

# Add labels and title
plt.xlabel('Number of Shots', )
plt.ylabel('Distance')
plt.title('Distance distributions Lin SMT')
plt.xticks([r + bar_width for r in range(len(x_values))], x_values)

# Add legend
plt.legend()

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Define explicit x and y values for the three datasets
x_values = [1000,10000,100000]

y_values3 = [0.054,0.0066,0.00058]

# Define the width of the bars
bar_width = 0.25

# Create an array of x positions for the first set of bars
r1 = np.arange(len(x_values))

# Create arrays of x positions for the second and third sets of bars, offset by the bar width
r2 = [x + bar_width for x in r1]


# Create the bar plot
plt.bar(r2, y_values3, color='orange', width=bar_width,  label='KL Divergence')

# Add labels and title
plt.xlabel('Number of Shots', )
plt.ylabel('Distance')
plt.title('Distance distributions Heuristic')
plt.xticks([r + bar_width for r in range(len(x_values))], x_values)

# Add legend
plt.legend()

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Define explicit x and y values for the three datasets
x_values = [1000,10000,100000]
y_values3 = [0.0154,0.0015,0.00016]

# Define the width of the bars
bar_width = 0.25

# Create an array of x positions for the first set of bars
r1 = np.arange(len(x_values))

# Create arrays of x positions for the second and third sets of bars, offset by the bar width
r2 = [x + bar_width for x in r1]


# Create the bar plot

plt.bar(r2, y_values3, color='orange', width=bar_width,  label='KL Divergence')

# Add labels and title
plt.xlabel('Number of Shots', )
plt.ylabel('Distance')
plt.title('Distance distributions ILP')
plt.xticks([r + bar_width for r in range(len(x_values))], x_values)

# Add legend
plt.legend()

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Define explicit x and y values for the three datasets
x_values =  [3,     4,  5,  6,  7,  8,  9,  10,     15,     25]
original =  [9,     13, 17, 21, 25, 29, 33, 37,     57,     97]
lin_smt =   [9,     17, 25, 36, 47, 57,  0,  0,      0,      0]
heuristic = [17,    34, 46, 57, 69, 81, 93, 105,    165,    0]
ilp =       [9,     17, 22, 28, 38, 57,  67,  78,    0,      0]
sabre =     [9,     17, 24, 39, 52, 62,  77,  87,   159,    314]

# Define the width of the bars
bar_width = 0.14

# Create an array of x positions for the first set of bars
r1 = np.arange(len(x_values))

# Create arrays of x positions for the second and third sets of bars, offset by the bar width
r2 = [x + bar_width for x in r1]
r3 = [x + bar_width for x in r2]
r4 = [x + bar_width for x in r3]
r5= [x + bar_width for x in r4]

# Create the bar plot
plt.bar(r1, original, color='grey', width=bar_width,  label='Original')
plt.bar(r2, lin_smt, color='green', width=bar_width,  label='Lin SMT')
plt.bar(r3, ilp, color='blue', width=bar_width,  label='ILP')
plt.bar(r4, heuristic, color='orange', width=bar_width,  label='Heuristic')
plt.bar(r5, sabre, color='purple', width=bar_width,  label='SABRE')

# Add labels and title
plt.xlabel('Number of Qubits', )
plt.ylabel('Depth')
plt.title('Depth of mapped circuit')
plt.xticks([r + bar_width for r in range(len(x_values))], x_values)

# Add legend
plt.legend()

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.optimize import curve_fit

# Define explicit x and y values for the three datasets
x_values = [3,          4,          5,          6,          7,      8,          9,          10,     15,     25]
lin_smt = [2.27,        5.89,       14.86,      54.14,      781,    59561,          0,          0,      0,      0]
heuristic = [0.000137,  0.00032,    0.00077,    0.00144,    0.0026, 0.0087,     0.0108,     0.022,  0.13,   1.33]
ilp = [      0.009,     0.038,      0.08,       0.9,        16.2,   119,        482,        1921,      0,      0]
sabre = [    0.028,     0.03,       0.041,      0.027,      0.029,  0.027,      0.053,      0.057,  0.106,  0.404]


# Define the width of the bars
bar_width = 0.15

# Create an array of x positions for the first set of bars
r1 = np.arange(len(x_values))

# Create arrays of x positions for the second and third sets of bars, offset by the bar width
r2 = [x + bar_width for x in r1]
r3 = [x + bar_width for x in r2]
r4 = [x + bar_width for x in r3]


# Create the bar plot
plt.bar(r1, lin_smt, color='green', width=bar_width, label='Lin SMT')
plt.bar(r2, ilp, color='blue', width=bar_width,  label='ILP')
plt.bar(r3, heuristic, color='orange', width=bar_width, label='Heuristic')
plt.bar(r4, sabre, color='purple', width=bar_width, label='SABRE')



plt.yscale('log')

# Add labels and title
plt.xlabel('Number of Qubits', )
plt.ylabel('Time [lg(s)]')
plt.title('Execution time')
plt.xticks([r + bar_width for r in range(len(x_values))], x_values)

# Add legend
plt.legend()

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.optimize import curve_fit

# Define explicit x and y values for the datasets
x_values = [3, 4, 5, 6, 7, 8, 9, 10, 15, 25]
heuristic = [0.000137, 0.00032, 0.00077, 0.00144, 0.0026, 0.0087, 0.0108, 0.022, 0.13, 1.34]
sabre = [0.028, 0.03, 0.041, 0.027, 0.029, 0.027, 0.053, 0.057, 0.106, 0.404]

# Define the width of the bars
bar_width = 0.15

# Create arrays of x positions for the bar sets, offset by the bar width
r3 = np.arange(len(x_values))
r4 = r3 + bar_width

# Create the bar plot
#plt.bar(r3, heuristic, color='orange', width=bar_width, label='Heuristic')
#plt.bar(r4, sabre, color='purple', width=bar_width, label='SABRE')

# Fit the exponential curves
def exp_func(t, a, b):
    return a * np.exp(b * t)

x_val = np.array(x_values)

# Fit heuristic data
popt_h, _ = curve_fit(exp_func, x_values, heuristic, p0=(1, 0.1))
y_fit_h = exp_func(x_val, *popt_h)
plt.plot(x_val, y_fit_h, 'orange',label='Heuristic Fit')

# Fit sabre data
popt_s, _ = curve_fit(exp_func, x_values, sabre, p0=(1, 0.1))
y_fit_s = exp_func(x_val, *popt_s)
plt.plot(x_val, y_fit_s,'purple', label='SABRE Fit')


# Fit ilp data
popt_i, _ = curve_fit(exp_func, x_values, sabre, p0=(1, 0.1))
y_fit_ilp = exp_func(x_val, 0.0010348468562876695, 1.4503263958024333)
plt.plot(x_val, y_fit_ilp,'blue', label='ilp Fit')

# Fit lin smt data
popt_s, _ = curve_fit(exp_func, x_values, sabre, p0=(1, 0.1))
y_fit_smt = exp_func(x_val,  7.4095700531096915e-06, 2.6390338260900825)
plt.plot(x_val, y_fit_smt, 'green',label='Lin_SMT Fit')

# Set y-axis to logarithmic scale
plt.yscale('log')

# Add labels and title
plt.xlabel('Number of Qubits')
plt.ylabel('Time [lg(s)]')
plt.title('Execution Time')


# Add legend
plt.legend()

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.optimize import curve_fit

# Define explicit x and y values for the datasets
x_values = [3, 4, 5, 6, 7, 8, 9, 10, 15, 25]
x_values_ilp = [3,          4,          5,          6,          7,      8,          9 , 10]
x_values_smt = [3,          4,          5,          6,          7    , 8   ]
heuristic = [0.000137, 0.00032, 0.00077, 0.00144, 0.0026, 0.0087, 0.0108, 0.022, 0.13, 1.34]
sabre = [0.028, 0.03, 0.041, 0.027, 0.029, 0.027, 0.053, 0.057, 0.106, 0.404]
lin_smt = [2.27,        5.89,       14.86,      54.14,      781    , 59561   ]
ilp = [      0.009,     0.038,      0.08,       0.9,        16.2,   119,        482    ,1921  ]



# Define the width of the bars
bar_width = 0.15

# Create arrays of x positions for the bar sets, offset by the bar width
r3 = np.arange(len(x_values))
r4 = r3 + bar_width

# Create the bar plot
#plt.bar(r3, heuristic, color='orange', width=bar_width, label='Heuristic')
#plt.bar(r4, sabre, color='purple', width=bar_width, label='SABRE')

# Fit the exponential curves
def exp_func(t, a, b):
    return a * np.exp(b * t)

x_val = np.array(x_values)
x_val_ilp = np.array(x_values_ilp)
x_val_smt = np.array(x_values_smt)

# Fit heuristic data
popt_h, _ = curve_fit(exp_func, x_values, heuristic, p0=(1, 0.1))
y_fit_h = exp_func(x_val, *popt_h)
plt.plot(x_val, y_fit_h, 'orange',label='Heuristic Fit')

# Fit sabre data
popt_s, _ = curve_fit(exp_func, x_values, sabre, p0=(1, 0.1))
y_fit_s = exp_func(x_val, *popt_s)
plt.plot(x_val, y_fit_s,'purple', label='SABRE Fit')


# Fit ilp data
popt_i, _ = curve_fit(exp_func, x_val_ilp, ilp, p0=(1, 0.1))
y_fit_ilp = exp_func(x_val_ilp, *popt_i)
plt.plot(x_val_ilp, y_fit_ilp,'blue', label='ilp Fit')

# Fit lin smt data
popt_l, _ = curve_fit(exp_func, x_val_smt, lin_smt, p0=(1, 0.1), maxfev = 6000)
y_fit_smt = exp_func(x_val_smt, *popt_l)
plt.plot(x_val_smt, y_fit_smt, 'green',label='Lin_SMT Fit')

# Set y-axis to logarithmic scale
plt.yscale('log')

# Add labels and title
plt.xlabel('Number of Qubits')
plt.ylabel('Time [lg(s)]')
plt.title('Execution Time')


# Add legend
plt.legend()

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.optimize import curve_fit

# Define explicit x and y values for the datasets
x_values = [3,          4,          5,          6,          7,      8,          9,          10,     15,     25]
x_values_ilp = [3,          4,          5,          6,          7,      8,          9      ,10   ]
x_values_smt = [3,          4,          5,          6,          7   ,8    ]
heuristic = [0.000137,  0.00032,    0.00077,    0.00144,    0.0026, 0.0087,     0.0108,     0.022,  0.13,   1.33]
sabre = [    0.028,     0.03,       0.041,      0.027,      0.029,  0.027,      0.053,      0.057,  0.106,  0.404]
lin_smt = [2.27,        5.89,       14.86,      54.14,      781     ,59561  ]
ilp = [      0.009,     0.038,      0.08,       0.9,        16.2,   119,        482    ,1921  ]


# Define the width of the bars
bar_width = 0.15

# Create arrays of x positions for the bar sets, offset by the bar width
r3 = np.arange(len(x_values))
r4 = r3 + bar_width

# Create the bar plot
#plt.bar(r3, heuristic, color='orange', width=bar_width, label='Heuristic')
#plt.bar(r4, sabre, color='purple', width=bar_width, label='SABRE')

degree=3

# Fit heuristic data
coeff_heu = np.polyfit( x_values, heuristic, degree)
polynomial_heu = np.poly1d(coeff_heu)
y_poly_heu = polynomial_heu(x_values)
#plt.plot(x_values, y_poly_heu, 'orange',label='Heuristic Fit')

# Fit sabre data
coeff_sabre = np.polyfit( x_values, sabre, degree)
polynomial_sabre = np.poly1d(coeff_sabre)
y_poly_sabre = polynomial_sabre(x_values)
#plt.plot(x_values, y_poly_sabre, 'purple',label='Sabre Fit')

# Fit ilp data
coeff_ilp = np.polyfit( x_values_ilp, ilp, degree)
polynomial_ilp = np.poly1d(coeff_ilp)
y_poly_ilp = polynomial_ilp(x_values_ilp)
plt.plot(x_values_ilp, y_poly_ilp, 'blue',label='ilp Fit')

# Fit lin smt data
coeff_smt = np.polyfit( x_values_smt, lin_smt, degree)
polynomial_smt = np.poly1d(coeff_smt)
y_poly_smt = polynomial_smt(x_values_smt)
plt.plot(x_values_smt, y_poly_smt, 'green',label='SMT Fit')


# Set y-axis to logarithmic scale
#plt.yscale('log')

# Add labels and title
plt.xlabel('Number of Qubits')
plt.ylabel('Time [s]')
plt.title('Execution Time')


# Add legend
plt.legend()

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.optimize import curve_fit

# Define explicit x and y values for the datasets
x_values = [3,          4,          5,          6,          7,      8,          9,          10,     15,     25]
x_values_ilp = [3,          4,          5,          6,          7,      8,          9         ]
x_values_smt = [3,          4,          5,          6,          7       ]
heuristic = [0.000137,  0.00032,    0.00077,    0.00144,    0.0026, 0.0087,     0.0108,     0.022,  0.13,   1.33]
sabre = [    0.028,     0.03,       0.041,      0.027,      0.029,  0.027,      0.053,      0.057,  0.106,  0.404]
lin_smt = [2.27,        5.89,       14.86,      54.14,      781       ]
ilp = [      0.009,     0.038,      0.08,       0.9,        16.2,   119,        482      ]


# Define the width of the bars
bar_width = 0.15

# Create arrays of x positions for the bar sets, offset by the bar width
r3 = np.arange(len(x_values))
r4 = r3 + bar_width

# Create the bar plot
#plt.bar(r3, heuristic, color='orange', width=bar_width, label='Heuristic')
#plt.bar(r4, sabre, color='purple', width=bar_width, label='SABRE')

degree=6

# Fit heuristic data
coeff_heu = np.polyfit( x_values, heuristic, degree)
polynomial_heu = np.poly1d(coeff_heu)
y_poly_heu = polynomial_heu(x_values)
plt.plot(x_values, y_poly_heu, 'orange',label='Heuristic Fit')

# Fit sabre data
coeff_sabre = np.polyfit( x_values, sabre, degree)
polynomial_sabre = np.poly1d(coeff_sabre)
y_poly_sabre = polynomial_sabre(x_values)
plt.plot(x_values, y_poly_sabre, 'purple',label='Sabre Fit')

# Fit ilp data
coeff_ilp = np.polyfit( x_values_ilp, ilp, degree)
polynomial_ilp = np.poly1d(coeff_ilp)
y_poly_ilp = polynomial_ilp(x_values)
plt.plot(x_values, y_poly_ilp, 'blue',label='ilp Fit')

# Fit lin smt data
coeff_smt = np.polyfit( x_values_smt, lin_smt, degree)
polynomial_smt = np.poly1d(coeff_smt)
y_poly_smt = polynomial_smt(x_values)
plt.plot(x_values, y_poly_smt, 'green',label='SMT Fit')


# Set y-axis to logarithmic scale
plt.yscale('log')

# Add labels and title
plt.xlabel('Number of Qubits')
plt.ylabel('Time [lg(s)]')
plt.title('Execution Time')


# Add legend
plt.legend()

# Show the plot
plt.show()
# Out:
# /tmp/ipykernel_4348/3589695318.py:47: RankWarning: Polyfit may be poorly conditioned
#   coeff_smt = np.polyfit( x_values_smt, lin_smt, degree)

# %%
from sklearn.metrics import r2_score


r2_heuristic_poly=r2_score(heuristic,y_poly_heu)
r2_heuristic_exp=r2_score(heuristic,y_fit_h)
if (r2_heuristic_poly>r2_heuristic_exp):
    print(" heu poly")
    print(r2_heuristic_poly,r2_heuristic_exp)
else:
    print("heu exp")
    print(r2_heuristic_poly,r2_heuristic_exp)


r2_heuristic_poly=r2_score(sabre,y_poly_sabre)
r2_heuristic_exp=r2_score(sabre,y_fit_s)
if (r2_heuristic_poly>r2_heuristic_exp):
    print(" sabre poly")
    print(r2_heuristic_poly,r2_heuristic_exp)
else:
    print("sabre exp")
    print(r2_heuristic_poly,r2_heuristic_exp)


r2_heuristic_poly=r2_score(ilp ,y_poly_ilp)
r2_heuristic_exp=r2_score(ilp,y_fit_ilp)
if (r2_heuristic_poly>r2_heuristic_exp):
    print(" ilp poly")
    print(r2_heuristic_poly,r2_heuristic_exp)
else:
    print("ilp exp")
    print(r2_heuristic_poly,r2_heuristic_exp)

r2_heuristic_poly=r2_score(lin_smt ,y_poly_smt)
r2_heuristic_exp=r2_score(lin_smt,y_fit_smt)
if (r2_heuristic_poly>r2_heuristic_exp):
    print(" smt poly")
    print(r2_heuristic_poly,r2_heuristic_exp)
else:
    print("smt exp")
    print(r2_heuristic_poly,r2_heuristic_exp)
# Out:
#  heu poly
# 0.9999121101486567 0.9991683355843884
#  sabre poly
# 0.9963383193370468 0.9952678838547698
# ilp exp
# 0.971324660224936 0.9999235794654222
# smt exp
# 0.955810378440359 0.9999992575964944

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.optimize import curve_fit

# Define explicit x and y values for the datasets
x_values = [3,          4,          5,          6,          7,      8,          9,          ]
lin_smt = [2.27,        5.89,       14.86,      54.14,      781,    0,          0,          ]
ilp = [      0.009,     0.038,      0.08,       0.9,        16.2,   119,        482,        ]



# Define the width of the bars
bar_width = 0.15

# Create arrays of x positions for the bar sets, offset by the bar width
r3 = np.arange(len(x_values))
r4 = r3 + bar_width

# Create the bar plot
#plt.bar(r3, heuristic, color='orange', width=bar_width, label='Heuristic')
#plt.bar(r4, sabre, color='purple', width=bar_width, label='SABRE')

degree=5


# Fit ilp data
coeff_ilp = np.polyfit( x_values, ilp, degree)
polynomial_ilp = np.poly1d(coeff_ilp)
y_poly_ilp = polynomial_ilp(x_values)
plt.plot(x_values, y_poly_ilp, 'blue',label='ilp Fit')

# Fit lin smt data
coeff_smt = np.polyfit( x_values, lin_smt, degree)
polynomial_smt = np.poly1d(coeff_smt)
y_poly_smt = polynomial_smt(x_values)
#plt.plot(x_values, y_poly_smt, 'green',label='SMT Fit')

# Set y-axis to logarithmic scale
#plt.yscale('log')

# Add labels and title
plt.xlabel('Number of Qubits')
plt.ylabel('Time [lg(s)]')
plt.title('Execution Time')


# Add legend
plt.legend()

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.optimize import curve_fit

# Define explicit x and y values for the datasets
x_values = [3, 4, 5, 6, 7, 8, 9]
ilp = [      0.009,     0.038,      0.08,       0.9,        16.2,   119,        482]
lin_smt = [2.27,        5.89,       14.86,      54.14,      781]

# Define the width of the bars
bar_width = 0.15

# Create arrays of x positions for the bar sets, offset by the bar width
r3 = np.arange(len(x_values))
r4 = r3 + bar_width

# Create the bar plot
#plt.bar(r3, heuristic, color='orange', width=bar_width, label='Heuristic')
#plt.bar(r4, sabre, color='purple', width=bar_width, label='SABRE')

# Fit the exponential curves
def exp_func(t, a, b):
    return a * np.exp(b * t)

# Fit ilp data
popt_s, _ = curve_fit(exp_func, x_values, ilp, p0=(1, 0.1))
y_fit_ilp = exp_func(x_fit, *popt_s)
plt.plot(x_fit, y_fit_ilp, label='ilp Fit')

# Set y-axis to logarithmic scale
#plt.yscale('log')

# Add labels and title
plt.xlabel('Number of Qubits')
plt.ylabel('Time [lg(s)]')
plt.title('Execution Time')


# Add legend
plt.legend()

# Show the plot
plt.show()
print("Amplitude (a):", popt_s[0])
print("Decay/Growth Rate (b):", popt_s[1])
# Out:
# Amplitude (a): 0.0010348468562876695
# Decay/Growth Rate (b): 1.4503263958024333

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.optimize import curve_fit

# Define explicit x and y values for the datasets
x_values = [3,          4,          5,          6,          7]
lin_smt = [2.27,        5.89,       14.86,      54.14,      781]

# Define the width of the bars
bar_width = 0.15

# Create arrays of x positions for the bar sets, offset by the bar width
r3 = np.arange(len(x_values))
r4 = r3 + bar_width

# Create the bar plot
#plt.bar(r3, heuristic, color='orange', width=bar_width, label='Heuristic')
#plt.bar(r4, sabre, color='purple', width=bar_width, label='SABRE')

# Fit the exponential curves
def exp_func(t, a, b):
    return a * np.exp(b * t)

# Fit ilp data
popt_s, _ = curve_fit(exp_func, x_values, lin_smt, p0=(1, 0.1))
y_fit_ilp = exp_func(x_fit, *popt_s)
plt.plot(x_fit, y_fit_ilp, label='ilp Fit')

# Set y-axis to logarithmic scale
#plt.yscale('log')

# Add labels and title
plt.xlabel('Number of Qubits')
plt.ylabel('Time [lg(s)]')
plt.title('Execution Time')


# Add legend
plt.legend()

# Show the plot
plt.show()
print("Amplitude (a):", popt_s[0])
print("Decay/Growth Rate (b):", popt_s[1])
# Out:
# Amplitude (a): 7.4095700531096915e-06
# Decay/Growth Rate (b): 2.6390338260900825
